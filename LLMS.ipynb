# %% [markdown]
# <a href="https://colab.research.google.com/github/soundaryavettri/Inlustro-training-/blob/main/LLMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from diffusers import StableDiffusionPipeline
import torch
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cpu")
prompt = "A futuristic city skyline at sunset"
image = pipe(prompt).images[0]
image.show()
image.save("generated_image.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
model = GenerativeModel("gemini-1.5-pro")
r = model.generate_content("Who are you?")
print(r.text)
# Out:
# I am a large language model, trained by Google.

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
model = GenerativeModel("gemini-1.5-pro")
print("Welcome to AI chatpot! Type 'exit' to stop.")
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
       break
    response = model.generate_content(user_input)
    print("AI:", response.text)
# Out:
# Welcome to AI chatpot! Type 'exit' to stop.
# You: Hi
# AI: Hi there! How can I help you today?
#
# You: How are you?
# AI: I am doing well, thank you for asking. How are you today?  As a large language model, I don't experience emotions or feelings like humans do, but I'm functioning optimally and ready to assist you with any questions or tasks you have.
#
# You:  I am fine.
# AI: That's good to hear!  Is there anything I can help you with today?
#
# You: Tell me about yourself
# AI: I am a large language model, trained by Google.  I don't have a physical body or personal experiences like humans do.  I exist only as code and data stored on Google's computers.
#
# ...

# %%
pip install deep_translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.6 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator
def translate_text(text, target_language):
    translator = GoogleTranslator(source='auto', target=target_language)
    return translator.translate(text)
text = "Hello, how are you?"
target_language = "hi"
translated_text = translate_text(text, target_language)
print(f"Original: {text}")
print(f"Translated ({target_language}): {translated_text}")
# Out:
# Original: Hello, how are you?
# Translated (hi): नमस्ते, आप कैसे हैं?
