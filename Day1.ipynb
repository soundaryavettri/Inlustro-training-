# %% [markdown]
# <a href="https://colab.research.google.com/github/soundaryavettri/Inlustro-training-/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x="soundarya"
y="sangavi"
print(x)
print(y)
# Out:
# soundarya
# sangavi

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
price=9.99
print(price)
# Out:
# 9.99

# %%
is_valid=True
print(is_valid)
# Out:
# True

# %%
x,y,z=10,20,30
print(x,y,z)
# Out:
# 10 20 30

# %%
p=q=r=100
print(p,q,r)
# Out:
# 100 100 100

# %%
age=25
print(age)
age=30
print(age)
# Out:
# 25
# 30

# %%
value=50
del value
#print(value)
#this will cause an error since value

# %%
message="Hello,World!"
print(len(message))
# Out:
# 12

# %%
data=42
data=str(data)
print(data)
# Out:
# 42

# %%
num=5
if num>0:
  print("positive number")
# Out:
# positive number

# %%
age=20
if age>=18:
  print("eligible to vote")
else:
    print("not eligible to vote")
# Out:
# eligible to vote

# %%
num=-3
if num>0:
  print("positive")
elif num<0:
    print("negative")
else:
      print("zero")
# Out:
# negative

# %%
num=7
if num%2==0:
  print("even")
else:
    print("odd")
# Out:
# odd

# %%
num=8
if num>0:
  if num%2==0:
    print("positive and even")
# Out:
# positive and even

# %%
x=10
if x==0:
  print("python is cool")

# %%
num=12
print("Even" if num%2==0 else "odd")
# Out:
# Even

# %%
text="I love python programming."
if "python" in text:
  print("String contains 'python'")
# Out:
# String contains 'python'

# %%
num=15
if num%3==0 and num%5==0:
  print("Divisible by both 3 and 5")
else:
    print("Non divisible by both 3 and 5")
# Out:
# Divisible by both 3 and 5

# %%
year=2024
if(year%4==0 and year%100!=0)or(year%400==0):
  print("leap year")
else:
  print("not a leap year")
# Out:
# leap year
